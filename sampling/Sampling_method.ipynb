# %% [markdown]
# ## Sampling methods

# %%
from IPython.display import Image, display
display(Image(filename='sampling.jpeg', width=600, height=600))

# %% [markdown]
# Most easy way is "undersampling" but it ocurred large data reduction.
# it will make the number of data for the most smallest number of class.
# "Oversampling" is opposite way it will make new data for other classes. (but it will ocurr overfitting"

# %%
from IPython.display import Image, display
display(Image(filename='undersample.jpeg', width=600, height=600))

# %% [markdown]
# "Weighted randome sampling" is good, "weighted loss function" is used at Pytouch

# %% [markdown]
# Evaluation metric is important but you should not work only "Acuracy" careful about "F1-score" including "precison", "recall", and "AUC, ROC curve"

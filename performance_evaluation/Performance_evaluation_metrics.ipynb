# %% [markdown]
# ## Model Performance evaluation metrics

# %% [markdown]
# 1. MSE = 1/n * Sum of Squares (predicted value y - actual value y)
# 2. RMSE = Root 1/n * Sum of Squares (predicted value y - actual value y)
# 3. MAE = 1/n * Sum of absolute value (predicted value y - actual value y)
# 4. MARE (Mean Absolute Relative Error)
#
#    = 1/n * Sum of absolute value (predicted value y - actual value y) / actual value y
# 5. R square
# 6. Adjusted R square

# %%
## 1~4 An accuracy value close to zero in measures indicates good performance

# %%
## 1. MSE is sensitive when data contains outliers

# %%
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y_test, y_pred)

# %%
## 2. RMSE: It is Squares of residuals, so the result is highly affected if residual is big
##          It is easy to explain the result because it is same unit of dependent variable (Root)

# %%
## Sklearn does not provide directly, so we should define a function
# 1)
from sklearn.metrics import mean_squared_log_error
def RMSE(y_test, y_pred):
    return np.sqrt(mean_squared_error(y_test, y_pred))
RMSE = RMSE(y_test, y_pred)

# %%
# 2)
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)

# %% [markdown]
# 3. MAE : MAE treats all errors equally, so it does not emphasize larger errors as much as MSE or RMSE.

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_test, y_pred)

# %% [markdown]
# 4. MARE : Especially when comparing model performance across datasets with different scales or magnitudes

# %% [markdown]
# 5. R square is especially for Model Comparison: R-squared can be useful for comparing the explanatory power of different models on the same dataset.

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_test, y_pred)

# %%
## R square (explanatory power) is frequently used for regression models
## MAE, MSE, RMSE (Accuracy) are more used for classification models
## -> + Precision, Recall, F1-score
## Close to 1, this model explains well from data
## How the model explain well about data fluctuation

# %%
from IPython.display import Image, display
display(Image(filename='r_square2.jpeg', width=500, height=500))

# %% [markdown]
# 6. Adjusted R square

# %%
## When number of independent variables is more than two, we should use adjusted R square fomula.

# %%
from IPython.display import Image, display
display(Image(filename='r_square.jpeg', width=500, height=500))

# %%
## n is number of data, k is number of independent variable (features)
## As the k (number of variables) value increases, the overall value decreases. 
## Therefore, the disadvantage of the existing coefficient of determination 
## that the value increases as the number of variables increases is supplemented

# %%
## 같은 데이터를 활용해 여러가지 모델의 설명력을 비교할때 사용됨 ()
